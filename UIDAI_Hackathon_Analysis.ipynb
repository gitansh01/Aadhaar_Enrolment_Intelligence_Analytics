# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %% [markdown]
# # **Data_Aadhar_Enrolment**

# %%
df1 = pd.read_csv("/UIDAI/api_data_aadhar_enrolment/api_data_aadhar_enrolment_0_500000.csv")
df2 = pd.read_csv("/UIDAI/api_data_aadhar_enrolment/api_data_aadhar_enrolment_1000000_1006029.csv")
df3 = pd.read_csv("/UIDAI/api_data_aadhar_enrolment/api_data_aadhar_enrolment_500000_1000000.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2587210993.py in <cell line: 0>()
# ----> 1 df1 = pd.read_csv("/UIDAI/api_data_aadhar_enrolment/api_data_aadhar_enrolment_0_500000.csv")
#       2 df2 = pd.read_csv("/UIDAI/api_data_aadhar_enrolment/api_data_aadhar_enrolment_1000000_1006029.csv")
#       3 df3 = pd.read_csv("/UIDAI/api_data_aadhar_enrolment/api_data_aadhar_enrolment_500000_1000000.csv")
#
# NameError: name 'pd' is not defined

# %%
df1.head()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            500000 non-null  object
#  1   state           500000 non-null  object
#  2   district        500000 non-null  object
#  3   pincode         500000 non-null  int64
#  4   age_0_5         500000 non-null  int64
#  5   age_5_17        500000 non-null  int64
#  6   age_18_greater  500000 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 26.7+ MB

# %%
combined = pd.concat([df1, df2, df3], ignore_index=True)
combined.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
combined.shape          # rows, columns
combined.columns        # column names
combined.isnull().sum() # missing values
combined.duplicated().sum()  # duplicates
# Out:
# np.int64(22957)

# %%
combined = combined.drop_duplicates()
combined.shape
# Out:
# (983072, 7)

# %%
combined.isnull().sum()
# Out:
# date              0
# state             0
# district          0
# pincode           0
# age_0_5           0
# age_5_17          0
# age_18_greater    0
# dtype: int64

# %%
combined.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'age_0_5', 'age_5_17',
#        'age_18_greater'],
#       dtype='object')

# %%
combined.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 983072 entries, 0 to 1004911
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            983072 non-null  object
#  1   state           983072 non-null  object
#  2   district        983072 non-null  object
#  3   pincode         983072 non-null  int64
#  4   age_0_5         983072 non-null  int64
#  5   age_5_17        983072 non-null  int64
#  6   age_18_greater  983072 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 60.0+ MB

# %% [markdown]
# **api_data_aadhar_demographic**

# %%
import pandas as pd
de1 = pd.read_csv("/UIDAI/api_data_aadhar_demographic/api_data_aadhar_demographic_0_500000.csv")
de2 = pd.read_csv("/UIDAI/api_data_aadhar_demographic/api_data_aadhar_demographic_500000_1000000.csv")
de3 = pd.read_csv("/UIDAI/api_data_aadhar_demographic/api_data_aadhar_demographic_1000000_1500000.csv")
de4 = pd.read_csv("/UIDAI/api_data_aadhar_demographic/api_data_aadhar_demographic_1500000_2000000.csv")
de5 = pd.read_csv("/UIDAI/api_data_aadhar_demographic/api_data_aadhar_demographic_2000000_2071700.csv")

# %%
de1.shape
de2.shape
de3.shape
de1.columns
de2.columns
de3.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'demo_age_5_17',
#        'demo_age_17_'],
#       dtype='object')

# %%
de_combined = pd.concat([de1, de2, de3], ignore_index=True)
de_combined.shape
# Out:
# (1500000, 6)

# %%
de_combined = de_combined.drop_duplicates()
de_combined.shape
# Out:
# (1291855, 6)

# %%
de_combined.isnull().sum()
# Out:
# date             0
# state            0
# district         0
# pincode          0
# demo_age_5_17    0
# demo_age_17_     0
# dtype: int64

# %%
de_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1291855 entries, 0 to 1499999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   date           1291855 non-null  object
#  1   state          1291855 non-null  object
#  2   district       1291855 non-null  object
#  3   pincode        1291855 non-null  int64
#  4   demo_age_5_17  1291855 non-null  int64
#  5   demo_age_17_   1291855 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 69.0+ MB

# %% [markdown]
# **api_data_aadhar_biometric**

# %%
bio1 = pd.read_csv("/UIDAI/api_data_aadhar_biometric/api_data_aadhar_biometric_0_500000.csv")
bio2 = pd.read_csv("/UIDAI/api_data_aadhar_biometric/api_data_aadhar_biometric_1000000_1500000.csv")
bio3 = pd.read_csv("/UIDAI/api_data_aadhar_biometric/api_data_aadhar_biometric_1500000_1861108.csv")
bio4 = pd.read_csv("/UIDAI/api_data_aadhar_biometric/api_data_aadhar_biometric_500000_1000000.csv")

# %%
bio1.shape
# Out:
# (500000, 6)

# %%
bio4.shape
# Out:
# (500000, 6)

# %%
bio1.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'bio_age_5_17', 'bio_age_17_'], dtype='object')

# %%
bio2.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'bio_age_5_17', 'bio_age_17_'], dtype='object')

# %%
bio_combined = pd.concat([bio1, bio2, bio3,bio4], ignore_index=True)
bio_combined.shape
# Out:
# (1861108, 6)

# %%
bio_combined = bio_combined.drop_duplicates()
bio_combined.shape
# Out:
# (1766212, 6)

# %%
bio_combined.isnull().sum()
# Out:
# date            0
# state           0
# district        0
# pincode         0
# bio_age_5_17    0
# bio_age_17_     0
# dtype: int64

# %%
bio_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1766212 entries, 0 to 1860557
# Data columns (total 6 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   date          object
#  1   state         object
#  2   district      object
#  3   pincode       int64
#  4   bio_age_5_17  int64
#  5   bio_age_17_   int64
# dtypes: int64(3), object(3)
# memory usage: 94.3+ MB

# %% [markdown]
# **Combined csv**

# %%
combined.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'age_0_5', 'age_5_17',
#        'age_18_greater'],
#       dtype='object')

# %%
de_combined.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'demo_age_5_17',
#        'demo_age_17_'],
#       dtype='object')

# %%
bio_combined.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'bio_age_5_17', 'bio_age_17_'], dtype='object')

# %%
combined.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
de_combined.head()
# Out:
#          date           state    district  pincode  demo_age_5_17  \
# 0  01-03-2025   Uttar Pradesh   Gorakhpur   273213             49
# 1  01-03-2025  Andhra Pradesh    Chittoor   517132             22
# 2  01-03-2025         Gujarat      Rajkot   360006             65
# 3  01-03-2025  Andhra Pradesh  Srikakulam   532484             24
# 4  01-03-2025       Rajasthan     Udaipur   313801             45
#
#    demo_age_17_
# 0           529
# 1           375
# 2           765
# 3           314
# 4           785

# %%
bio_combined.head()
# Out:
#          date              state      district  pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh   123029           280
# 1  01-03-2025              Bihar     Madhepura   852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3  01-03-2025              Bihar       Bhojpur   802158           256
# 4  01-03-2025         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_
# 0          577
# 1          369
# 2         1091
# 3          980
# 4          815

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 983072 entries, 0 to 1004911
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            983072 non-null  object
#  1   state           983072 non-null  object
#  2   district        983072 non-null  object
#  3   pincode         983072 non-null  int64
#  4   age_0_5         983072 non-null  int64
#  5   age_5_17        983072 non-null  int64
#  6   age_18_greater  983072 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 60.0+ MB

# %%
de_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1291855 entries, 0 to 1499999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   date           1291855 non-null  object
#  1   state          1291855 non-null  object
#  2   district       1291855 non-null  object
#  3   pincode        1291855 non-null  int64
#  4   demo_age_5_17  1291855 non-null  int64
#  5   demo_age_17_   1291855 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 69.0+ MB

# %%
bio_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1766212 entries, 0 to 1860557
# Data columns (total 6 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   date          object
#  1   state         object
#  2   district      object
#  3   pincode       int64
#  4   bio_age_5_17  int64
#  5   bio_age_17_   int64
# dtypes: int64(3), object(3)
# memory usage: 94.3+ MB

# %%
combined['date'] = pd.to_datetime(combined['date'], dayfirst=True)
de_combined['date'] = pd.to_datetime(de_combined['date'], dayfirst=True)
bio_combined['date'] = pd.to_datetime(bio_combined['date'], dayfirst=True)

# %%
de_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1291855 entries, 0 to 1499999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   date           1291855 non-null  datetime64[ns]
#  1   state          1291855 non-null  object
#  2   district       1291855 non-null  object
#  3   pincode        1291855 non-null  int64
#  4   demo_age_5_17  1291855 non-null  int64
#  5   demo_age_17_   1291855 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 69.0+ MB

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 983072 entries, 0 to 1004911
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            983072 non-null  datetime64[ns]
#  1   state           983072 non-null  object
#  2   district        983072 non-null  object
#  3   pincode         983072 non-null  int64
#  4   age_0_5         983072 non-null  int64
#  5   age_5_17        983072 non-null  int64
#  6   age_18_greater  983072 non-null  int64
# dtypes: datetime64[ns](1), int64(4), object(2)
# memory usage: 60.0+ MB

# %%
de_combined.rename(
    columns={'demo_age_17_':'demo_age_18_plus'},
    inplace=True
)

bio_combined.rename(
    columns={'bio_age_17_':'bio_age_18_plus'},
    inplace=True
)

# %%
bio_combined.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'bio_age_5_17',
#        'bio_age_18_plus'],
#       dtype='object')

# %%
de_combined.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'demo_age_5_17',
#        'demo_age_18_plus'],
#       dtype='object')

# %%
merged = combined.merge(
    de_combined,
    on=['date','state','district','pincode'],
    how='left'
).merge(
    bio_combined,
    on=['date','state','district','pincode'],
    how='left'
)

# %%
merged.shape
# Out:
# (983072, 11)

# %%
merged.shape
merged.head()
merged.info()
merged.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 983072 entries, 0 to 983071
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              983072 non-null  datetime64[ns]
#  1   state             983072 non-null  object
#  2   district          983072 non-null  object
#  3   pincode           983072 non-null  int64
#  4   age_0_5           983072 non-null  int64
#  5   age_5_17          983072 non-null  int64
#  6   age_18_greater    983072 non-null  int64
#  7   demo_age_5_17     540544 non-null  float64
#  8   demo_age_18_plus  540544 non-null  float64
#  9   bio_age_5_17      726111 non-null  float64
#  10  bio_age_18_plus   726111 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(4), object(2)
# memory usage: 82.5+ MB
# date                     0
# state                    0
# district                 0
# pincode                  0
# age_0_5                  0
# ...

# %%
merged.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'age_0_5', 'age_5_17',
#        'age_18_greater', 'demo_age_5_17', 'demo_age_18_plus', 'bio_age_5_17',
#        'bio_age_18_plus'],
#       dtype='object')

# %%
merged.describe()
# Out:
#                                 date        pincode        age_0_5  \
# count                         983072  983072.000000  983072.000000
# mean   2025-10-23 05:35:51.258097920  518469.318987       3.534216
# min              2025-03-02 00:00:00  100000.000000       0.000000
# 25%              2025-09-18 00:00:00  363621.000000       1.000000
# 50%              2025-10-26 00:00:00  517401.000000       2.000000
# 75%              2025-11-15 00:00:00  700093.000000       3.000000
# max              2025-12-31 00:00:00  855456.000000    2688.000000
# std                              NaN  205492.403834      17.726248
#
#             age_5_17  age_18_greater  demo_age_5_17  demo_age_18_plus  \
# count  983072.000000   983072.000000  540544.000000     540544.000000
# mean        1.720026        0.169328       2.376632         21.675919
# min         0.000000        0.000000       0.000000          0.000000
# 25%         0.000000        0.000000       0.000000          4.000000
# ...

# %%
merged['state'].nunique(), merged['district'].nunique()
merged['state'].unique()[:10]
# Out:
# array(['Meghalaya', 'Karnataka', 'Uttar Pradesh', 'Bihar', 'Maharashtra',
#        'Haryana', 'Rajasthan', 'Punjab', 'Delhi', 'Madhya Pradesh'],
#       dtype=object)

# %%
merged.isnull().sum()
# Out:
# date                     0
# state                    0
# district                 0
# pincode                  0
# age_0_5                  0
# age_5_17                 0
# age_18_greater           0
# demo_age_5_17       442528
# demo_age_18_plus    442528
# bio_age_5_17        256961
# bio_age_18_plus     256961
# dtype: int64

# %% [markdown]
# Fill Missing Values

# %%
merged[['demo_age_5_17','demo_age_18_plus',
        'bio_age_5_17','bio_age_18_plus']] = \
merged[['demo_age_5_17','demo_age_18_plus',
        'bio_age_5_17','bio_age_18_plus']].fillna(0)

# %%
merged.isnull().sum()
# Out:
# date                0
# state               0
# district            0
# pincode             0
# age_0_5             0
# age_5_17            0
# age_18_greater      0
# demo_age_5_17       0
# demo_age_18_plus    0
# bio_age_5_17        0
# bio_age_18_plus     0
# dtype: int64

# %%
merged['state'].nunique(), merged['district'].nunique()
# Out:
# (55, 985)

# %%
merged['state'].unique()[:10]
# Out:
# array(['Meghalaya', 'Karnataka', 'Uttar Pradesh', 'Bihar', 'Maharashtra',
#        'Haryana', 'Rajasthan', 'Punjab', 'Delhi', 'Madhya Pradesh'],
#       dtype=object)

# %% [markdown]
# **Insight-1: State-wise Aadhaar Enrolment **
#
# *   Top 10 strongest states

# %%
state_enrol = merged.groupby('state')[['age_0_5','age_5_17','age_18_greater']].sum()
state_enrol.sort_values('age_18_greater', ascending=False).head(10)
# Out:
#                 age_0_5  age_5_17  age_18_greater
# state
# Meghalaya         21072     53089           35078
# Assam            137970     64834           22555
# Uttar Pradesh    511727    473205           17699
# Gujarat          188709     70270           16063
# Bihar            254911    327043           11799
# Karnataka        176178     33402           10038
# Madhya Pradesh   363244    115172            9476
# West Bengal      270390     90321            8495
# Maharashtra      274274     81069            8103
# Rajasthan        224977    110131            5483

# %% [markdown]
# **Insight-2: District Hotspot Analysis**

# %% [markdown]
# Which districts enrolled the most adults?

# %%
merged.groupby('district')['age_18_greater'].sum().sort_values(ascending=False).head(10)
# Out:
# district
# East Khasi Hills      9839
# West Khasi Hills      5259
# West Garo Hills       4532
# Bengaluru Urban       3796
# West Jaintia Hills    3793
# Bengaluru             3775
# Ri Bhoi               3359
# Sitamarhi             2694
# Bahraich              2274
# Golaghat              1879
# Name: age_18_greater, dtype: int64

# %% [markdown]
# **Insight-3: Time Trend (Monthly bases)**

# %%
monthly = merged.groupby(pd.Grouper(key='date', freq='M'))[['age_0_5','age_5_17','age_18_greater']].sum()
monthly
# Out:
# /tmp/ipython-input-705339671.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly = merged.groupby(pd.Grouper(key='date', freq='M'))[['age_0_5','age_5_17','age_18_greater']].sum()
#             age_0_5  age_5_17  age_18_greater
# date
# 2025-03-31     5367      7407            3808
# 2025-04-30   141154     91371           24913
# 2025-05-31    95342     71690           16584
# 2025-06-30    98943     99911           16880
# 2025-07-31   318352    263333           35183
# 2025-08-31        0         0               0
# 2025-09-30   995612    465401           14866
# 2025-10-31   536781    227415           15421
# 2025-11-30   742020    286115           24449
# 2025-12-31   540818    178266           14358

# %% [markdown]
# **Insight-4: Demographic vs Biometric Performance**

# %%
demo_total = merged[['demo_age_5_17','demo_age_18_plus']].sum().sum()
bio_total  = merged[['bio_age_5_17','bio_age_18_plus']].sum().sum()

demo_total, bio_total
# Out:
# (np.float64(13001462.0), np.float64(19123282.0))

# %%
state_enrol.head()
# Out:
#                              age_0_5  age_5_17  age_18_greater
# state
# 100000                             0         1             213
# Andaman & Nicobar Islands        106         5               0
# Andaman and Nicobar Islands      363        27               0
# Andhra Pradesh                109389     13414            1465
# Arunachal Pradesh               1914      2176             150

# %%
monthly.head()
# Out:
#             age_0_5  age_5_17  age_18_greater
# date
# 2025-03-31     5367      7407            3808
# 2025-04-30   141154     91371           24913
# 2025-05-31    95342     71690           16584
# 2025-06-30    98943     99911           16880
# 2025-07-31   318352    263333           35183

# %% [markdown]
# **Insight — Monthly Growth Trend**

# %%
monthly["total"] = (
    monthly["age_0_5"] + monthly["age_5_17"] + monthly["age_18_greater"]
)

monthly["growth_percent"] = monthly["total"].pct_change() * 100
monthly
# Out:
#             age_0_5  age_5_17  age_18_greater    total  growth_percent
# date
# 2025-03-31     5367      7407            3808    16582             NaN
# 2025-04-30   141154     91371           24913   257438     1452.514775
# 2025-05-31    95342     71690           16584   183616      -28.675642
# 2025-06-30    98943     99911           16880   215734       17.491940
# 2025-07-31   318352    263333           35183   616868      185.939166
# 2025-08-31        0         0               0        0     -100.000000
# 2025-09-30   995612    465401           14866  1475879             inf
# 2025-10-31   536781    227415           15421   779617      -47.176090
# 2025-11-30   742020    286115           24449  1052584       35.012961
# 2025-12-31   540818    178266           14358   733442      -30.319860

# %% [markdown]
# **Insight — Which Age Group Dominates Monthly?**

# %%
monthly[["age_0_5","age_5_17","age_18_greater"]].sum()
# Out:
# age_0_5           3474389
# age_5_17          1690909
# age_18_greater     166462
# dtype: int64

# %% [markdown]
# ## **Visualization**

# %% [markdown]
# **Top 10 states — bar graph**

# %%
import matplotlib.pyplot as plt

top_states = state_enrol.sort_values('age_18_greater').tail(10)

top_states['age_18_greater'].plot(kind='barh')
plt.title("Top 10 States by Adult Aadhaar Enrolment")
plt.xlabel("Number of Enrolments")
plt.ylabel("State")
plt.show()

# %% [markdown]
# **Monthly trend — line graph**

# %%
monthly[['age_0_5','age_5_17','age_18_greater']].plot()
plt.title("Aadhaar Enrolment Trend Over Time")
plt.xlabel("Month")
plt.ylabel("Enrolments")
plt.show()

# %% [markdown]
# # **Meaningful Insights**

# %% [markdown]
# **top 1–3 states clearly**

# %%
state_enrol['total'] = state_enrol['age_0_5'] + state_enrol['age_5_17'] + state_enrol['age_18_greater']
top_states = state_enrol.sort_values("total", ascending=False).head(3)
top_states
# Out:
#                 age_0_5  age_5_17  age_18_greater    total
# state
# Uttar Pradesh    511727    473205           17699  1002631
# Bihar            254911    327043           11799   593753
# Madhya Pradesh   363244    115172            9476   487892

# %% [markdown]
# **best & worst month**

# %%
best_month = monthly.loc[monthly["total"].idxmax()]
worst_month = monthly.loc[monthly["total"].idxmin()]

best_month, worst_month
# Out:
# (age_0_5            995612.0
#  age_5_17           465401.0
#  age_18_greater      14866.0
#  total             1475879.0
#  growth_percent          inf
#  Name: 2025-09-30 00:00:00, dtype: float64,
#  age_0_5             0.0
#  age_5_17            0.0
#  age_18_greater      0.0
#  total               0.0
#  growth_percent   -100.0
#  Name: 2025-08-31 00:00:00, dtype: float64)

# %% [markdown]
# # **District Level Insights**

# %%
district = merged.groupby("district")[
    ["age_0_5","age_5_17","age_18_greater"]
].sum().sort_values("age_18_greater", ascending=False)

district.head(10)
# Out:
#                     age_0_5  age_5_17  age_18_greater
# district
# East Khasi Hills       4239     14578            9839
# West Khasi Hills       2392      8152            5259
# West Garo Hills        4507      6760            4532
# Bengaluru Urban       12111      7167            3796
# West Jaintia Hills     2374      5584            3793
# Bengaluru             20227      6655            3775
# Ri Bhoi                1332      4574            3359
# Sitamarhi             20358     18600            2694
# Bahraich              14491     22132            2274
# Golaghat               5461      3989            1879

# %% [markdown]
# # **Comparing Demographic vs Biometric**

# %%
state_compare = merged.groupby("state")[
    ["demo_age_18_plus","bio_age_18_plus"]
].sum()

state_compare["gap"] = (
    state_compare["demo_age_18_plus"] - state_compare["bio_age_18_plus"]
)

state_compare.sort_values("gap", ascending=False).head(10)
# Out:
#                 demo_age_18_plus  bio_age_18_plus        gap
# state
# Uttar Pradesh          2334458.0        1175335.0  1159123.0
# Bihar                  1554349.0         751854.0   802495.0
# West Bengal            1170310.0         413193.0   757117.0
# Telangana               380535.0         194446.0   186089.0
# Assam                   278724.0         165883.0   112841.0
# Manipur                  90197.0          32946.0    57251.0
# Delhi                   276652.0         228682.0    47970.0
# Jharkhand               320324.0         274543.0    45781.0
# Andhra Pradesh          281993.0         249334.0    32659.0
# Odisha                  214109.0         204526.0     9583.0

# %%
merged.to_csv("final_uidai_clean.csv", index=False)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7fcf4c06-9c90-49f5-ad5f-48bab241c5c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7fcf4c06-9c90-49f5-ad5f-48bab241c5c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'api_data_aadhar_demographic_0_500000.csv',
#  'api_data_aadhar_enrolment_500000_1000000.csv',
#  'api_data_aadhar_demographic_1000000_1500000.csv',
#  'api_data_aadhar_biometric_0_500000.csv',
#  'api_data_aadhar_demographic_2000000_2071700.csv',
#  'api_data_aadhar_biometric_500000_1000000.csv',
#  'api_data_aadhar_enrolment_0_500000.csv',
#  'api_data_aadhar_demographic_1500000_2000000.csv',
#  'api_data_aadhar_biometric_1500000_1861108.csv',
#  'api_data_aadhar_biometric_1000000_1500000.csv',
#  'api_data_aadhar_demographic_500000_1000000.csv',
#  'api_data_aadhar_enrolment_1000000_1006029.csv',
#  'sample_data']

# %%
import pandas as pd

demo_files = [
    'api_data_aadhar_demographic_0_500000.csv',
    'api_data_aadhar_demographic_500000_1000000.csv',
    'api_data_aadhar_demographic_1000000_1500000.csv',
    'api_data_aadhar_demographic_1500000_2000000.csv',
    'api_data_aadhar_demographic_2000000_2071700.csv'
]

demo_df = pd.concat([pd.read_csv(f) for f in demo_files], ignore_index=True)

demo_df.head()
# Out:
#          date           state    district  pincode  demo_age_5_17  \
# 0  01-03-2025   Uttar Pradesh   Gorakhpur   273213             49
# 1  01-03-2025  Andhra Pradesh    Chittoor   517132             22
# 2  01-03-2025         Gujarat      Rajkot   360006             65
# 3  01-03-2025  Andhra Pradesh  Srikakulam   532484             24
# 4  01-03-2025       Rajasthan     Udaipur   313801             45
#
#    demo_age_17_
# 0           529
# 1           375
# 2           765
# 3           314
# 4           785

# %%
bio_files = [
    'api_data_aadhar_biometric_0_500000.csv',
    'api_data_aadhar_biometric_500000_1000000.csv',
    'api_data_aadhar_biometric_1000000_1500000.csv',
    'api_data_aadhar_biometric_1500000_1861108.csv'
]

bio_df = pd.concat([pd.read_csv(f) for f in bio_files], ignore_index=True)

bio_df.head()
# Out:
#          date              state      district  pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh   123029           280
# 1  01-03-2025              Bihar     Madhepura   852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3  01-03-2025              Bihar       Bhojpur   802158           256
# 4  01-03-2025         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_
# 0          577
# 1          369
# 2         1091
# 3          980
# 4          815

# %%
enrol_files = [
    'api_data_aadhar_enrolment_0_500000.csv',
    'api_data_aadhar_enrolment_500000_1000000.csv',
    'api_data_aadhar_enrolment_1000000_1006029.csv'
]

enrol_df = pd.concat([pd.read_csv(f) for f in enrol_files], ignore_index=True)

enrol_df.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
print("Demographic records:", demo_df.shape)
print("Biometric records:", bio_df.shape)
print("Enrolment records:", enrol_df.shape)
# Out:
# Demographic records: (2071700, 6)
# Biometric records: (1861108, 6)
# Enrolment records: (1006029, 7)

# %% [markdown]
# ## **1. Aadhaar Enrolment → Demographic → Biometric Drop-off**

# %%
import pandas as pd
import matplotlib.pyplot as plt

enrol_count = enrol_df.shape[0]
demo_count = demo_df.shape[0]
bio_count = bio_df.shape[0]

stages = ['Enrolment', 'Demographic Capture', 'Biometric Capture']
counts = [enrol_count, demo_count, bio_count]

plt.figure(figsize=(8,5))
plt.bar(stages, counts)
plt.title("Aadhaar Enrolment Pipeline Drop-off")
plt.ylabel("Number of Records")
plt.xlabel("Stage")
plt.show()

# %% [markdown]
# # --There is a visible reduction from enrolment to biometric capture, indicating operational or demographic barriers that UIDAI can target.

# %%
bio_df.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'bio_age_5_17', 'bio_age_17_'], dtype='object')

# %%
# Inspect possible status columns
for col in bio_df.columns:
    if bio_df[col].nunique() <= 5:
        print(col, bio_df[col].unique())

# %% [markdown]
# ## **2. State-wise Biometric Capture Distribution by Age Group**

# %%
bio_state = (
    bio_df
    .groupby('state')[['bio_age_5_17', 'bio_age_17_']]
    .sum()
    .reset_index()
)

bio_state.head()
# Out:
#                          state  bio_age_5_17  bio_age_17_
# 0    Andaman & Nicobar Islands           405         1979
# 1  Andaman and Nicobar Islands         11401         6913
# 2               Andhra Pradesh       2241448      1473144
# 3            Arunachal Pradesh         42894        29500
# 4                        Assam        596624       386098

# %%
bio_state['total_biometrics'] = (
    bio_state['bio_age_5_17'] + bio_state['bio_age_17_']
)

bio_state['age_5_17_%'] = (
    bio_state['bio_age_5_17'] / bio_state['total_biometrics']
) * 100

bio_state['age_17_plus_%'] = (
    bio_state['bio_age_17_'] / bio_state['total_biometrics']
) * 100

bio_state.head()
# Out:
#                          state  bio_age_5_17  bio_age_17_  total_biometrics  \
# 0    Andaman & Nicobar Islands           405         1979              2384
# 1  Andaman and Nicobar Islands         11401         6913             18314
# 2               Andhra Pradesh       2241448      1473144           3714592
# 3            Arunachal Pradesh         42894        29500             72394
# 4                        Assam        596624       386098            982722
#
#    age_5_17_%  age_17_plus_%
# 0   16.988255      83.011745
# 1   62.252921      37.747079
# 2   60.341701      39.658299
# 3   59.250767      40.749233
# 4   60.711371      39.288629

# %%
import matplotlib.pyplot as plt

top_states = bio_state.sort_values(
    'age_17_plus_%', ascending=False
).head(10)

plt.figure(figsize=(10,5))
plt.bar(top_states['state'], top_states['age_17_plus_%'])
plt.title("Top 10 States by Adult (17+) Biometric Capture Share")
plt.ylabel("Percentage (%)")
plt.xlabel("State")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insight: State-wise Biometric Capture Distribution by Age Group
#
# The proportion of biometric captures for adults (17+) varies significantly
# across states. States with higher adult biometric shares may reflect
# migration patterns, delayed enrolments, or update-driven biometric capture.
#
# **Policy Implication:**
# UIDAI can use this insight to optimize enrolment infrastructure, staffing,
# and device allocation based on state-level demographic demand.

# %% [markdown]
# # **3. Age vs Biometric Failure**

# %%
bio_df['date'] = pd.to_datetime(bio_df['date'], dayfirst=True)

# %%
bio_time = (
    bio_df
    .groupby(pd.Grouper(key='date', freq='M'))[
        ['bio_age_5_17', 'bio_age_17_']
    ]
    .sum()
    .reset_index()
)

bio_time.head()
# Out:
# /tmp/ipython-input-926296820.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   .groupby(pd.Grouper(key='date', freq='M'))[
#         date  bio_age_5_17  bio_age_17_
# 0 2025-03-31       3733578      4588644
# 1 2025-04-30       4356896      4284783
# 2 2025-05-31       3868247      4011709
# 3 2025-06-30       3710149      4189140
# 4 2025-07-31       4499057      5293495

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(bio_time['date'], bio_time['bio_age_5_17'], label='Age 5–17')
plt.plot(bio_time['date'], bio_time['bio_age_17_'], label='Age 17+')

plt.title("Biometric Capture Trends Over Time by Age Group")
plt.xlabel("Time")
plt.ylabel("Number of Biometric Captures")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### --Insight: Biometric Capture Trends by Age Group Over Time
#
# Biometric captures for adults (17+) consistently exceed those for minors,
# indicating sustained demand driven by new enrolments, updates, and
# migration-related re-capture. Temporal variations can inform UIDAI's
# capacity planning and seasonal staffing decisions.

# %% [markdown]
# ## **4. District-level Aadhaar Activity Concentration**

# %%
district_activity = (
    demo_df
    .groupby(['state', 'district'])
    .size()
    .reset_index(name='record_count')
)
district_activity.head()
# Out:
#                          state       district  record_count
# 0                       100000         100000             2
# 1    Andaman & Nicobar Islands       Andamans           314
# 2    Andaman & Nicobar Islands       Nicobars             4
# 3    Andaman & Nicobar Islands  South Andaman           195
# 4  Andaman and Nicobar Islands        Nicobar           128

# %%
top_districts = district_activity.sort_values(
    'record_count', ascending=False
).head(10)

top_districts
# Out:
#                state            district  record_count
# 1045     West Bengal   North 24 Parganas         12994
# 554      Maharashtra                Pune         12450
# 1012     West Bengal          Barddhaman         12349
# 18    Andhra Pradesh       East Godavari         12186
# 449           Kerala            Thrissur         12097
# 50    Andhra Pradesh       West Godavari         10007
# 437           Kerala           Ernakulam          9895
# 390        Karnataka           Bengaluru          9776
# 446           Kerala            Palakkad          9726
# 448           Kerala  Thiruvananthapuram          9673

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.barh(
    top_districts['district'],
    top_districts['record_count']
)
plt.title("Top 10 Districts by Aadhaar Demographic Activity")
plt.xlabel("Number of Records")
plt.ylabel("District")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### --Insight: District-level Aadhaar Activity Concentration
#
# A small number of districts account for a disproportionately high share
# of Aadhaar demographic records. These hotspots may correspond to urban
# centers, migration hubs, or regions with higher update activity.
#
# **Policy Implication:**
# UIDAI can use district-level concentration insights to optimize enrolment
# center placement, staffing levels, and infrastructure investments.

# %% [markdown]
# # **5. Enrolment Load vs Biometric Load Across States**

# %%
enrol_state = (
    enrol_df
    .groupby('state')
    .size()
    .reset_index(name='enrolment_count')
)

enrol_state.head()
# Out:
#                          state  enrolment_count
# 0                       100000               22
# 1    Andaman & Nicobar Islands              103
# 2  Andaman and Nicobar Islands              289
# 3               Andhra Pradesh            65658
# 4            Arunachal Pradesh             1601

# %%
bio_state_load = (
    bio_df
    .groupby('state')[['bio_age_5_17', 'bio_age_17_']]
    .sum()
    .reset_index()
)

bio_state_load['biometric_count'] = (
    bio_state_load['bio_age_5_17'] + bio_state_load['bio_age_17_']
)

bio_state_load.head()
# Out:
#                          state  bio_age_5_17  bio_age_17_  biometric_count
# 0    Andaman & Nicobar Islands           405         1979             2384
# 1  Andaman and Nicobar Islands         11401         6913            18314
# 2               Andhra Pradesh       2241448      1473144          3714592
# 3            Arunachal Pradesh         42894        29500            72394
# 4                        Assam        596624       386098           982722

# %%
state_load = enrol_state.merge(
    bio_state_load[['state', 'biometric_count']],
    on='state',
    how='inner'
)

state_load.head()
# Out:
#                          state  enrolment_count  biometric_count
# 0    Andaman & Nicobar Islands              103             2384
# 1  Andaman and Nicobar Islands              289            18314
# 2               Andhra Pradesh            65658          3714592
# 3            Arunachal Pradesh             1601            72394
# 4                        Assam            31827           982722

# %%
state_load['bio_enrol_ratio'] = (
    state_load['biometric_count'] / state_load['enrolment_count']
)

state_load = state_load.sort_values(
    'bio_enrol_ratio', ascending=False
)

state_load.head()
# Out:
#                      state  enrolment_count  biometric_count  bio_enrol_ratio
# 13                   Delhi             6804          1304362       191.705173
# 9   Dadra and Nagar Haveli              162            27235       168.117284
# 7             Chhattisgarh            18550          2648729       142.788625
# 26             Maharashtra            77191          9226139       119.523507
# 25          Madhya Pradesh            50225          5923771       117.944669

# %%
import matplotlib.pyplot as plt

top_mismatch = state_load.head(10)

plt.figure(figsize=(10,5))
plt.bar(
    top_mismatch['state'],
    top_mismatch['bio_enrol_ratio']
)
plt.title("Top 10 States by Biometric-to-Enrolment Load Ratio")
plt.xlabel("State")
plt.ylabel("Biometric / Enrolment Ratio")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### --Insight: Enrolment vs Biometric Load Mismatch Across States
#
# Some states exhibit a disproportionately high biometric capture volume
# relative to enrolment counts. This suggests increased biometric updates,
# retries, or migration-driven re-capture activity.
#
# **Policy Implication:**
# UIDAI can use this ratio to rebalance biometric infrastructure, deploy
# additional devices, and optimize staffing in high-load states while
# rationalizing resources in low-load regions.

# %% [markdown]
# # ***FINAL CONCLUSION***

# %% [markdown]
# This analysis explored anonymized Aadhaar enrolment, demographic, and biometric
# datasets to understand operational patterns, geographic concentration, and
# infrastructure demand across India. The study was conducted using only the
# aggregated attributes provided in the dataset, ensuring methodological
# correctness and transparency.
#
# ### **Key Findings**
#
# 1. **Aadhaar Process Flow Insight**
#    The enrolment and biometric datasets highlight the multi-stage nature of
#    Aadhaar operations, with biometric capture volumes providing an important
#    indicator of downstream operational load beyond initial enrolments.
#
# 2. **State-wise Biometric Demand Variation**
#    Significant variation exists across states in terms of biometric capture
#    volumes, particularly between age groups (5–17 and 17+). This reflects
#    differences in enrolment maturity, update frequency, and population
#    mobility.
#
# 3. **Temporal Trends in Biometric Activity**
#    Time-series analysis reveals consistent biometric activity over time, with
#    adults (17+) accounting for the majority of captures. These trends can be
#    leveraged for forecasting future workload and planning seasonal or
#    event-driven demand.
#
# 4. **District-level Aadhaar Activity Hotspots**
#    Aadhaar-related activity is highly concentrated in a limited number of
#    districts, likely corresponding to urban centers, migration hubs, and
#    high-population regions. This uneven distribution suggests the need for
#    location-specific infrastructure planning.
#
# 5. **Enrolment vs Biometric Load Mismatch**
#    Several states exhibit a disproportionately high biometric-to-enrolment
#    ratio, indicating that biometric operations are driven not only by new
#    enrolments but also by updates, re-captures, and mobility-related changes.
#    This mismatch highlights potential stress points in biometric infrastructure.
#
# ### **Policy Implications**
#
# - **Targeted Infrastructure Allocation:**
#   States and districts with high biometric load relative to enrolment volumes
#   should be prioritized for additional devices, staffing, and technical audits.
#
# - **Data-driven Capacity Planning:**
#   Temporal and geographic trends can support predictive planning for enrolment
#   centers, helping UIDAI optimize resource deployment and reduce citizen wait
#   times.
#
# - **Focused Regional Interventions:**
#   District-level hotspot identification enables more granular policy
#   interventions instead of uniform nationwide strategies.
#
# ### **Future Scope**
#
# Future work could integrate population benchmarks, center-level metadata, or
# update-type classifications (if available) to further refine operational
# efficiency analysis and enable predictive modeling for Aadhaar service demand.
#
# Overall, this analysis demonstrates how anonymized, aggregated Aadhaar data can
# be transformed into actionable insights that support evidence-based governance,
# operational optimization, and inclusive digital identity management.
